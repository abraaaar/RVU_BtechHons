# %%
# !pip install langchain langchain_community sentence-transformers faiss-cpu

# %%
from langchain.document_loaders import TextLoader
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
# Load the text document
loader = TextLoader("/content/sample.txt")
documents = loader.load()
# Create embeddings and vector store
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
vectorstore = FAISS.from_documents(documents, embeddings)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
from langchain.chains import RetrievalQA
retriever = vectorstore.as_retriever()

# %%
# !pip install huggingface_hub langchain_huggingface

# %%
from langchain.llms import HuggingFaceHub

import os

# %%
os.environ["HUGGINGFACEHUB_API_TOKEN"] = "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"

# %%
from langchain_huggingface import HuggingFaceEndpoint
API_TOKEN_KEY="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"
llm = HuggingFaceHub(repo_id="gpt2", model_kwargs={"temperature": 0.7})

# %%
# from langchain.llms import HuggingFaceInference
# llm = HuggingFaceInference(model_name="gpt-neo-125M")
qa_chain = RetrievalQA.from_llm(llm, retriever=retriever)

# %%
query ="tell me what is the difference betwen encode and decode"
response = qa_chain.run(query)
print(response)
# Out:
# Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer.
#
# Context:
# In Deep Learning, Many Complex problems can be solved by constructing better neural network architecture. The RNN(Recurrent Neural Network) and its variants are much useful in sequence to sequence learning. The RNN variant LSTM (Long Short-term Memory) is the most used cell in seq-seq learning tasks.
#
# The encoder-decoder architecture for recurrent neural networks is the standard neural machine translation method that rivals and in some cases outperforms classical statistical machine translation methods.
#
# This architecture is very new, having only been pioneered in 2014, although, has been adopted as the core technology inside Google’s translate service.
#
# Encoder-Decoder Model
# There are three main blocks in the encoder-decoder model,
#
# Encoder
# Hidden Vector
# Decoder
# ...

# %%
from langchain.document_loaders import TextLoader
loader = TextLoader("/content/sample.txt")
documents = loader.load()

# %%
from langchain.chains.summarize import load_summarize_chain
chain = load_summarize_chain(llm, chain_type="stuff")
chain.run(documents)
# Out:
# 'Write a concise summary of the following:\n\n\n"In Deep Learning, Many Complex problems can be solved by constructing better neural network architecture. The RNN(Recurrent Neural Network) and its variants are much useful in sequence to sequence learning. The RNN variant LSTM (Long Short-term Memory) is the most used cell in seq-seq learning tasks.\n\nThe encoder-decoder architecture for recurrent neural networks is the standard neural machine translation method that rivals and in some cases outperforms classical statistical machine translation methods.\n\nThis architecture is very new, having only been pioneered in 2014, although, has been adopted as the core technology inside Google’s translate service.\n\nEncoder-Decoder Model\nThere are three main blocks in the encoder-decoder model,\n\nEncoder\nHidden Vector\nDecoder\nThe Encoder will convert the input sequence into a single-dimensional vector (hidden vector). The decoder will convert the hidden vector into the output sequence.\
# ...

# %%
from langchain.chains.llm import LLMChain
generator = LLMChain(llm=llm,prompt="Write a story about a robot who dreams of becoming a chef.")
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# <ipython-input-47-84ecd3f4b418> in <cell line: 2>()
#       1 from langchain.chains.llm import LLMChain
# ----> 2 generator = LLMChain(llm=llm,prompt="Write a story about a robot who dreams of becoming a chef.")
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warn_if_direct_instance(self, *args, **kwargs)
#     213                         warned = True
#     214                         emit_warning()
# --> 215                     return wrapped(self, *args, **kwargs)
#     216
#     217                 obj.__init__ = functools.wraps(obj.__init__)(  # type: ignore[misc]
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/load/serializable.py in __init__(self, *args, **kwargs)
#     111     def __init__(self, *args: Any, **kwargs: Any) -> None:
#     112         """"""
# ...

# %%
from langchain.prompts import PromptTemplate

prompt_template = PromptTemplate(
    input_variables=[],
    template="Write a story about a robot who dreams of becoming a chef."
)

generator = LLMChain(llm=llm, prompt=prompt_template)

story = generator.run(prompt="What is the solar system made up of")
print(story)
# Out:
# Write a story about a robot who dreams of becoming a chef. Find out what makes a good chef.
#
# Write a story about a robot who dreams of becoming a chef. Find out what makes a good chef. Are they good at their jobs? If so, how important is their intelligence?
#
# If so, how important is their intelligence? Can the robot get through to the next level? If so, what is the job's most important trait?
#
# If so, what is the job's most important trait? Will the robot get through to
